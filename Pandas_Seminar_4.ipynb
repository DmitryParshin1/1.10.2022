# %% [markdown]
# <a href="https://colab.research.google.com/github/DmitryParshin1/1.10.2022/blob/master/Pandas_Seminar_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Считываем датасет
df = pd.read_csv('laptops_10 (2).csv', encoding = 'latin-1')
df.head()
# Out:
#   Company      Product   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69       Intel
# 1        Intel HD Graphics 6000  macOS    1.34       898.94       Intel
# 2         Intel HD Graphics 620  No OS    1.86       575.00       Intel
# 3            AMD Radeon Pro 455  macOS    1.83      2537.45       Intel
# 4  Intel Iris Plus Graphics 650  macOS    1.37      1803.60       Intel
#
#    Memory_Amount   Memory_Type
# 0            128           SSD
# ...

# %% [markdown]
# 1.1 Изучить количество памяти с помощью matplitlip<br>
# 1.2 Изучить стоимость ноутбуков с помощью matplitlip<br>
# 1.3 Изучить вес ноутбуков с помощью matplitlip<br>
# - постоить график
# - назвать график
# - сделать именоване осей Х и Y
# - сделать выводы

# %%
plt.hist(df['Memory_Amount'])
plt.xlabel('GB')
plt.ylabel('Count')
plt.title('количество памяти')
# Out:
# Text(0.5, 1.0, 'количество памяти')

# %%
plt.hist(df['Price_euros'])
plt.xlabel('euro')
plt.ylabel('Count')
plt.title('стоимость')
# Out:
# Text(0.5, 1.0, 'стоимость')

# %%
plt.hist(df['Weight'])
plt.xlabel('KG')
plt.ylabel('Count')
plt.title('Weight')
# Out:
# Text(0.5, 1.0, 'Weight')

# %% [markdown]
# 2.1 Изучите распределение типов носителя<br>
# 2.2 Изучите распределение компаний производителей<br>
# 2.1 Изучите распределение операционной системы<br>
# 2.1 Изучите распределение компаний производителей CPU<br>
# - постройте график
# - сделайте выводы

# %%
data = df['Memory_Type'].value_counts()
data
# Out:
# SSD             641
# HDD             576
# FlashStorage     74
# Hybrid           12
# Name: Memory_Type, dtype: int64

# %%
plt.pie(data.values, labels= data.index, autopct='%1.2f%%')
plt.legend(data.index);

# %%
data = df['Company'].value_counts()
plt.bar(data.index, data.values)
plt.xticks(rotation = 40);

# %%
data = df['OpSys'].value_counts()
plt.bar(data.index, data.values)
plt.xticks(rotation = 40);

# %%
data = df['Cpu_Company'].value_counts()
plt.pie(data.values, labels= data.index, autopct='%1.2f%%')
plt.legend(data.index);

# %% [markdown]
# Изучите взаимосвязь компаний производителей ноутбуков и компаний производителей процессов, используя сложенную или многорядовую столбчатую диаграмму процессоры от Sumsung не изучайте<br>
#
# 3.1 постройте график в абсолютных величинах<br>
# 3.2 постройте график в относительных величинах

# %%
data = pd.crosstab(index=df['Company'], columns=df['Cpu_Company'])
data = data.drop(columns=['Samsung']).reset_index()
data
# Out:
# Cpu_Company    Company  AMD  Intel
# 0                 Acer   10     93
# 1                Apple    0     21
# 2                 Asus   11    147
# 3                Chuwi    0      3
# 4                 Dell    0    297
# 5              Fujitsu    0      3
# 6               Google    0      3
# 7                   HP   25    249
# 8               Huawei    0      2
# 9                   LG    0      3
# 10              Lenovo   16    281
# 11                 MSI    0     54
# 12            Mediacom    0      7
# 13           Microsoft    0      6
# 14               Razer    0      7
# 15             Samsung    0      8
# 16             Toshiba    0     48
# 17                Vero    0      4
# 18              Xiaomi    0      4

# %%
n_ticks = np.arange(len(data))

plt.bar(n_ticks - 0.2, data['AMD'], width = 0.6)
plt.bar(n_ticks + 0.2, data['Intel'], width = 0.6)

plt.legend(['AMD', 'Intel'])
plt.title("Ноутбуки")
plt.grid()
plt.xticks(n_ticks, data['Company'], rotation = 50);

# %%
data = pd.crosstab(index=df['Company'], columns=df['Cpu_Company'], normalize = 'index')
data = data.drop(columns=['Samsung']).reset_index()
data
# Out:
# Cpu_Company    Company       AMD     Intel
# 0                 Acer  0.097087  0.902913
# 1                Apple  0.000000  1.000000
# 2                 Asus  0.069620  0.930380
# 3                Chuwi  0.000000  1.000000
# 4                 Dell  0.000000  1.000000
# 5              Fujitsu  0.000000  1.000000
# 6               Google  0.000000  1.000000
# 7                   HP  0.091241  0.908759
# 8               Huawei  0.000000  1.000000
# 9                   LG  0.000000  1.000000
# 10              Lenovo  0.053872  0.946128
# 11                 MSI  0.000000  1.000000
# 12            Mediacom  0.000000  1.000000
# 13           Microsoft  0.000000  1.000000
# 14               Razer  0.000000  1.000000
# 15             Samsung  0.000000  0.888889
# 16             Toshiba  0.000000  1.000000
# 17                Vero  0.000000  1.000000
# 18              Xiaomi  0.000000  1.000000

# %%
plt.bar(data['Company'], data['AMD'], width = 0.6)
plt.bar(data['Company'], data['Intel'], width = 0.6, bottom = data['AMD'])

plt.legend(['AMD', 'Intel'])
plt.title("Ноутбуки")
plt.grid()
plt.xticks(n_ticks, data['Company'], rotation = 50);

# %% [markdown]
# 4.1 Изучите взаимосвязь стоимости ноутбуков и компании производителя процессов<br>
# 4.2 Изучите взаимосвязь стоимости типа носителя памяти<br>
# 4.1 Изучите взаимосвязь стоимости ноутбуков и кол-во оеративной памяти<br>
# 4.1 Изучите взаимосвязь стоимости ноутбуков и компании производителя<br>
# - постройте график
# - назовите график
# - сделайте именование оси Х и Y
# - сделайте выводы

# %%
sns.boxplot(x = df['Price_euros'], y = df['Cpu_Company'], showfliers = False)
# Out:
# <Axes: xlabel='Price_euros', ylabel='Cpu_Company'>

# %%
sns.boxplot(x = df['Price_euros'], y = df['Memory_Type'], showfliers = False);

# %%
sns.boxplot(x = df['Price_euros'], y = df['Ram'], showfliers = False);

# %%
sns.boxplot(x = df['Price_euros'], y = df['Company'], showfliers = False);

# %% [markdown]
# ## постоиить матрцу кориляции

# %%
corr_matrix = df.corr()
corr_matrix = np.round(corr_matrix, 2)
corr_matrix
# Out:
# <ipython-input-42-fc27ce46bf07>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()
#                Inches  Weight  Price_euros  Memory_Amount
# Inches           1.00    0.83         0.07           0.27
# Weight           0.83    1.00         0.21           0.18
# Price_euros      0.07    0.21         1.00          -0.13
# Memory_Amount    0.27    0.18        -0.13           1.00

# %%
sns.heatmap(corr_matrix, annot = True, linewidths=5, cmap='coolwarm');
