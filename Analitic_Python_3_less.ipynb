# %% [markdown]
# <a href="https://colab.research.google.com/github/DmitryParshin1/1.10.2022/blob/master/Analitic_Python_3_less.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('laptop_price (1).csv', sep = ',', encoding='latin-1')
df.tail(5)
# Out:
#       laptop_ID Company                              Product  \
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1301            Notebook    15.6                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram              Memory  \
# ...

# %% [markdown]
# 1.1 Создать новый признак Cpu_Company, который будет содержать только<br> название фирмы, которая произвела CPU<br>
# 1.2 Создать новый признак Memory_Amount, который будет содержать только<br>  количество Gb памяти без указания типа носителя<br>
# 1.3 Создать новый признак Memory_Type, который будет содержать только тип<br>  носителя (HDD/SDD/др.)<br>
# 1.4 Удалите признаки Memory и ScreenResolution<br>

# %%
df['Cpu_Company'] = df['Cpu'].apply(lambda x: x.split(' ')[0])
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
def convert(x):
    x = x.split(' ')[0]
    if x.endswith('GB'):
        res = x.replace('GB', '')
    elif x.endswith('TB'):
        res = float(x.replace('TB', '')) * 1024
    return int(res)

df['Memory_Amount'] = df['Memory'].apply(convert)

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
def convert2(x):
    x = x.split(' ')
    x.pop(0)  # x = x[1:]
    return ' '.join(x)
    # ' '.join(x.split(' ')[1: ])

df['Memory_Type'] = df['Memory'].apply(convert2)
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
df.drop(columns=['Memory' ,'ScreenResolution'], inplace=True)
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros Cpu_Company  Memory_Amount    Memory_Type
# 0  1.37kg      1339.69       Intel            128            SSD
# 1  1.34kg       898.94       Intel            128  Flash Storage
# ...

# %% [markdown]
# 2.1 Создайте признак SSD, который изначально равен 0<br>
# 2.2 Поставьте в признаке SSD 1, если ноутбук действительно с типом носителя<br> SSD<br>
# 2.3 Уберите в признаке Weight значения 'kg' и поменяйте его тип данных на<br> вещественный

# %%
df['SSD'] = 0
df.loc[df['Memory_Type'] == 'SSD', 'SSD'] = 1
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros Cpu_Company  Memory_Amount    Memory_Type  SSD
# 0  1.37kg      1339.69       Intel            128            SSD    1
# ...

# %%
df['Weight'] = df['Weight'].str.replace('kg', '').astype('float64')
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros Cpu_Company  Memory_Amount    Memory_Type  SSD
# 0    1.37      1339.69       Intel            128            SSD    1
# ...

# %% [markdown]
# Создайте датафрейм с клиентами:<br>
# clients = pd.DataFrame({<br>
#     'client_id': [45, 32, 67, 33, 43],<br>
#     'laptop_id': [506, 398, 710, 120, 1999]<br>
# })<br>
# laptop_id - это индексы датафрейма с ноутбуками<br>
# 3.1 Присоедините к таблице clients данные по ноутбукам через метод join<br>
# 3.2 Присоедините к таблице clients данные по ноутбукам через метод merge<br>
# Это нужно, чтобы понимать, какие ноутбуки покупались клиентами<br>

# %%
clients = pd.DataFrame({
'client_id': [45, 32, 67, 33, 43],
'laptop_id': [506, 398, 710, 120, 1999]
})
display(clients)
# Out:
#    client_id  laptop_id
# 0         45        506
# 1         32        398
# 2         67        710
# 3         33        120
# 4         43       1999

# %%
clients = clients.set_index('laptop_id')
df2 = df.set_index('laptop_ID')

# %%
joined = clients.join(df2)
joined.head()
# Out:
#            client_id Company            Product  TypeName  Inches  \
# laptop_id
# 506               45  Lenovo      ThinkPad L570  Notebook    15.6
# 398               32     NaN                NaN       NaN     NaN
# 710               67  Lenovo  IdeaPad 320-15ABR  Notebook    15.6
# 120               33    Dell      Inspiron 7570  Notebook    15.6
# 1999              43     NaN                NaN       NaN     NaN
#
#                                    Cpu  Ram                    Gpu  \
# laptop_id
# 506         Intel Core i5 7200U 2.5GHz  8GB  Intel HD Graphics 620
# 398                                NaN  NaN                    NaN
# 710        AMD A12-Series 9720P 3.6GHz  8GB          AMD Radeon R7
# 120         Intel Core i7 8550U 1.8GHz  8GB   Nvidia GeForce 940MX
# 1999                               NaN  NaN                    NaN
#
#                 OpSys  Weight  Price_euros Cpu_Company  Memory_Amount  \
# laptop_id
# ...

# %%
clients = pd.DataFrame({
    'client_id': [45, 32, 67, 33, 43],
    'laptop_id': [506, 398, 710, 120, 1999]
})

# %%
merged = clients.merge(df, left_on='laptop_id', right_on='laptop_ID')
# merged = clients.merge(df, left_on='laptop_id', right_on='laptop_ID', how='left')
# merged = clients.merge(df, on='laptop_id')
merged
# Out:
#    client_id  laptop_id  laptop_ID Company            Product  TypeName  \
# 0         45        506        506  Lenovo      ThinkPad L570  Notebook
# 1         67        710        710  Lenovo  IdeaPad 320-15ABR  Notebook
# 2         33        120        120    Dell      Inspiron 7570  Notebook
#
#    Inches                          Cpu  Ram                    Gpu  \
# 0    15.6   Intel Core i5 7200U 2.5GHz  8GB  Intel HD Graphics 620
# 1    15.6  AMD A12-Series 9720P 3.6GHz  8GB          AMD Radeon R7
# 2    15.6   Intel Core i7 8550U 1.8GHz  8GB   Nvidia GeForce 940MX
#
#         OpSys  Weight  Price_euros Cpu_Company  Memory_Amount     Memory_Type  \
# 0  Windows 10    2.30       911.00       Intel            256             SSD
# 1  Windows 10    2.20       429.00         AMD           1024             HDD
# 2  Windows 10    2.16      1130.33       Intel            256  SSD +  1TB HDD
#
#    SSD
# 0    1
# 1    0
# 2    0

# %% [markdown]
# 4.1 Найдите среднюю стоимость ноутбуков в зависимости от компании<br> производителя<br>
# Отсортируйте от меньшей стоимости к большей<br>
# 4.2 Найдите минимальную, среднюю и максимальную стоимости ноутбуков в<br> зависимости от производителя процессора<br>
# 4.3 Постройте таблицу с подсчетом количества ноутбуков в данных в зависимости<br> от производителя CPU и ОЗУ<br>
# 4.4 Постройте таблицу с подсчетом средней стоимости ноутбуков в данных в<br> зависимости от операционной системы и GB памяти<br>

# %%
df.groupby('Company').agg({'Price_euros': 'mean'}).sort_values(by='Price_euros')
# Out:
#            Price_euros
# Company
# Vero        217.425000
# Mediacom    295.000000
# Chuwi       314.296667
# Acer        626.775825
# Fujitsu     729.000000
# HP         1067.774854
# Lenovo     1086.384444
# Asus       1104.169367
# Xiaomi     1133.462500
# Dell       1186.068990
# Toshiba    1267.812500
# Samsung    1413.444444
# Huawei     1424.000000
# Apple      1564.198571
# Microsoft  1612.308333
# Google     1677.666667
# MSI        1728.908148
# LG         2099.000000
# Razer      3346.142857

# %%
df.groupby('Cpu_Company').agg({'Price_euros': ['min', 'mean', 'max']})
# Out:
#             Price_euros
#                     min         mean     max
# Cpu_Company
# AMD               199.0   560.638871  2199.0
# Intel             174.0  1152.214145  6099.0
# Samsung           659.0   659.000000   659.0

# %%
df.pivot_table(index='Cpu_Company', columns='Ram', values='Weight', aggfunc='count', fill_value=0)
# Out:
# Ram          12GB  16GB  24GB  2GB  32GB  4GB  64GB  6GB  8GB
# Cpu_Company
# AMD             2     3     0    1     0   31     0   13   12
# Intel          23   197     3   21    17  343     1   28  607
# Samsung         0     0     0    0     0    1     0    0    0

# %%
round(df.pivot_table(index='OpSys', columns='Memory_Amount', values='Price_euros', aggfunc='mean', fill_value=0), 2)
# Out:
# Memory_Amount  8       16      32      64       128     180   240      256   \
# OpSys
# Android           0    0.00    0.00  434.00     0.00     0.0     0     0.00
# Chrome OS         0  305.38  412.45  774.33  1275.00     0.0     0  1559.00
# Linux             0    0.00    0.00    0.00   742.25     0.0     0   811.64
# Mac OS X          0    0.00    0.00    0.00  1099.00     0.0     0  1311.99
# No OS             0    0.00    0.00    0.00   562.14     0.0     0   782.99
# Windows 10     2249    0.00  270.00  499.72  1026.49  1073.5  3100  1334.46
# Windows 10 S      0    0.00    0.00  309.00  1039.00     0.0     0  1668.95
# Windows 7         0    0.00    0.00    0.00  1320.32  1199.0     0  1846.47
# macOS             0    0.00    0.00    0.00  1119.32     0.0     0  1600.37
#
# Memory_Amount    500   508      512      1024    2048
# OpSys
# Android          0.00     0     0.00     0.00    0.00
# Chrome OS        0.00     0  2199.00     0.00    0.00
# ...

# %% [markdown]
# 5.1 Ноутбуков каких компаний и с каким процессором больше?<br>
# 5.2 С каким типом памяти и с каким объемом памяти больше ноутбуков?<br>

# %%
pd.crosstab(index=df['Company'], columns=df['Cpu_Company'])
# Out:
# Cpu_Company  AMD  Intel  Samsung
# Company
# Acer          10     93        0
# Apple          0     21        0
# Asus          11    147        0
# Chuwi          0      3        0
# Dell           0    297        0
# Fujitsu        0      3        0
# Google         0      3        0
# HP            25    249        0
# Huawei         0      2        0
# LG             0      3        0
# Lenovo        16    281        0
# MSI            0     54        0
# Mediacom       0      7        0
# Microsoft      0      6        0
# Razer          0      7        0
# Samsung        0      8        1
# Toshiba        0     48        0
# Vero           0      4        0
# Xiaomi         0      4        0

# %%
pd.crosstab(index=df['Memory_Type'], columns=df['Memory_Amount'])
# Out:
# Memory_Amount             8     16    32    64    128   180   240   256   \
# Memory_Type
# Flash Storage                0     7    38    15     4     0     0     8
# Flash Storage +  1TB HDD     0     0     0     1     0     0     0     0
# HDD                          0     0     1     0     1     0     0     0
# HDD +  1TB HDD               0     0     0     0     0     0     0     0
# Hybrid                       0     0     0     0     0     0     0     0
# SSD                          1     3     6     1    76     5     1   412
# SSD +  1.0TB Hybrid          0     0     0     0     0     0     0     1
# SSD +  1TB HDD               0     0     0     0    94     0     0    73
# SSD +  256GB SSD             0     0     0     0     0     0     0     2
# SSD +  2TB HDD               0     0     0     0     2     0     0    10
# SSD +  500GB HDD             0     0     0     0     0     0     0     2
# SSD +  512GB SSD             0     0     0     0     0     0     0     0
#
# ...
